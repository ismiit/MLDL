# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=87fb5b29c1e33347c7f847796881a0cb&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])

# %%
df.shape
# Out:
# (20, 14)

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=87fb5b29c1e33347c7f847796881a0cb&language=en-US&page=2')
df = pd.DataFrame(response.json()['results'])

# %%
df
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /xs6awEGjnH3e36YSAromfYu3PBQ.jpg                 [12, 35]   40096
# 1   False  /lXhgCODAbBXL5buk9yEmTpOoOgR.jpg             [12, 14, 28]     122
# 2   False  /x4biAVdPVCghBlsVIzB6NmbghIz.jpg                     [37]     429
# 3   False  /qdIMHd4sEfJSckfVJfKQvisL02a.jpg          [35, 18, 10749]      13
# 4   False  /zoVeIgKzGJzpdG6Gwnr7iOYfIMU.jpg              [18, 10749]   11216
# 5   False  /qvZ91FwMq6O47VViAr8vZNQz3WI.jpg                 [28, 18]     346
# 6   False  /gavyCu1UaTaTNPsVaGXT6pe5u24.jpg                 [35, 18]     637
# 7   False  /yHtB4KHNigx3ZoxDvQbW2SOXGfq.jpg      [16, 10751, 12, 14]  441130
# 8   False  /gILte6Zd7m1YneIr6MVhh30S9pr.jpg                 [18, 80]     769
# 9   False  /uPYa165sraN2c8gZBM9C47g3JoU.jpg                 [18, 80]     311
# 10  False  /qknxyRgP6UTmwJ4B9tDAmzHMq7u.jpg          [10749, 16, 14]   92321
# ...

# %%
data = pd.DataFrame()

# %%
for i in range(1,486):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=87fb5b29c1e33347c7f847796881a0cb&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])
    data = data.append(df,ignore_index=True)

# %%
data.tail()
# Out:
#       adult                     backdrop_path    genre_ids      id  \
# 9695  False  /eWZQ2IkBHfltHKUylRyMF5tWzy2.jpg     [18, 53]  413992
# 9696  False  /qAwXM5ZTA2tEYkLHTQyd1xFyH0g.jpg         [35]  323676
# 9697  False  /aJg0c8F6jIR88B2PXi52twOSRaS.jpg  [35, 10751]   11317
# 9698  False  /6Egrh9rNwZc0VpPfdivaf4ElUc7.jpg  [35, 10751]   11011
# 9699  False  /qogeijTQKJB3XtopMolADVQcnBG.jpg     [37, 18]  492565
#
#      original_language  original_title  \
# 9695                en  Sweet Virginia
# 9696                en        The Boss
# 9697                en       My Girl 2
# 9698                en     Ri¢hie Ri¢h
# 9699                en         The Kid
#
#                                                overview  popularity  \
# 9695  A former rodeo star, now a motel manager, meet...      13.012
# 9696  A titan of industry is sent to prison after sh...      17.600
# 9697  Vada Sultenfuss has a holiday coming up, and a...      18.282
# ...

# %%
response = requests.get('https://amazon-product-reviews-keywords.p.rapidapi.com/product/reviews')

# %%
response
# Out:
# <Response [401]>
